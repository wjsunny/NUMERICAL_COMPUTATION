# %% [markdown]
# Perform the same computation as in Sec. 8.3, but determine
# the value of C required for the circuit to dissipate to 1% of its original
# value in t = 0.05 s, given R = 280 ohm, and L = 7.5 H.
# ![Annotation%202019-08-05%20231204.jpg](attachment:Annotation%202019-08-05%20231204.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def fncal(C):
    L = 7.5
    R = 280
    t = 0.05
    #q0/q(t)
    qq0 = 0.01
    fc = np.exp((-R*t)/(2*L))*np.cos(np.sqrt((1/(L*C))-(R/(2*L))**2)*t) - qq0
    return fc

def Bisection(xl, xu, err, fnc):
    print('Bisection')
    er = err+100
    i = 0
    xrn = 0
    fxl = fnc(xl)
    x = np.array([])
    y = np.array([])
    while not er <= err:
        i += 1
        x = np.append(x,i)
        xr = xrn
        xrn = (xl+xu)/2
        fxr = fnc(xrn)
        if not xrn == 0:
            er = np.abs(((xrn - xr) / xrn)) * 100
        y = np.append(y, er)
        if (fxl * fxr < 0):
            xu = xrn
        elif (fxl * fxr >0):
            xl = xrn
            fxl = fxr
        else:
            print('i = {:3d}, C = {:22}, error = {}%'.format(i,xrn,er))
            return x, y
            break
        print('i = {:3d}, C = {:22}, error = {}%'.format(i,xrn,er))
    return x, y

def FlasePosition(xl, xu, err, fnc):
    print('FlasePosition')
    xrn = 0
    i = 0
    er = err +100
    fxl = fnc(xl)
    fxu = fnc(xu)
    x = np.array([])
    y = np.array([])
    while not er <= err:
        i += 1
        x = np.append(x,i)
        xr = xrn
        xrn = xu-(fxu*(xl-xu))/(fxl - fxu)
        fxr = fnc(xrn)
        if not xrn == 0:
            er = np.abs((xrn - xr)/xrn) * 100
        y = np.append(y, er)
        if (fxl * fxr <0):
            xu = xrn
            fxu = fxr
        elif (fxl * fxr >0):
            xl = xrn
            fxl = fxr
        else:
            print('i = {:3d}, C = {:22}, error = {}%'.format(i,xrn,er))
            return x, y
            break
        print('i = {:3d}, C = {:22}, error = {}%'.format(i,xrn,er))
    return x, y

# %%
x1, y1 = Bisection(1e-7,1e-4,0.01,fncal)
x2, y2 = FlasePosition(1e-7,1e-4,0.01,fncal)

x = np.arange(1e-7,1e-4,1e-10)
#x = np.linspace(1e-10,1e-4,1000)
fig1 = plt.figure()
plt.title('Graph of Capacitor')
plt.plot(x, fncal(x))
plt.grid()
fig2 = plt.figure()
plt.title('Comparison')
plt.plot(x1, y1, label='Bisection')
plt.plot(x2, y2, label='FalsePosition')
plt.legend()
plt.grid()
plt.xlabel('Step')
plt.ylabel('%Error')
# Out:
# Bisection
# i =   1, C = 5.0050000000000004e-05, error = 100.0%
# i =   2, C = 2.5075000000000003e-05, error = 99.60119641076768%
# i =   3, C = 1.2587500000000001e-05, error = 99.20556107249257%
# i =   4, C =           1.883125e-05, error = 33.15632260205775%
# i =   5, C =          1.5709375e-05, error = 19.872687487567134%
# i =   6, C = 1.4148437500000001e-05, error = 11.032578685808943%
# i =   7, C =        1.492890625e-05, error = 5.227903082317232%
# i =   8, C =       1.4538671875e-05, error = 2.6841129530616077%
# i =   9, C =      1.43435546875e-05, error = 1.3603126404226635%
# i =  10, C =     1.424599609375e-05, error = 0.6848141267763008%
# i =  11, C =    1.4294775390625e-05, error = 0.34123863818798517%
# i =  12, C =   1.43191650390625e-05, error = 0.1703287054165892%
# i =  13, C =  1.430697021484375e-05, error = 0.08523694420009094%
# i =  14, C = 1.4300872802734375e-05, error = 0.04263664318593199%
# ...
